# %% [markdown]
# # Homework 4: Classification with kNN
#
# **Author:** Alejandro Monroy
#
# In this homework assignment we will apply knn to predict the drug type that is more suitable for a patient. We will also write code to compute confusion matrices and the most common classification metrics.
#
# **INSRUCTIONS:**
# - Coding questions:
#     - You need to write code wherever it says `# YOUR CODE HERE`.
#     - You are allowed to use functions and models from Sklearn/Pandas/Numpy by default **unless otherwise specified**.
# - Written questions:
#     - You need to write an answer/explanation wherever it says "YOUR ANSWER HERE".
#     - Make sure your answers are properly written and complete but also concise.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Data preparation [1.5 p.]
# The `drug` dataset provides information on drug classification based on patient demographics and diagnoses. A machine learning model is required to predict the appropriate drug type for each patient.
#
# [0.25 p.] Load the dataset `drug.csv` into a Pandas Dataframe and apply one-hot encoding to the categorical variables (set `drop_first=False`). Also, replace the labels in the `class` column by integers using the map defined in `index_to_class`.

# %% [markdown]
# ❗️ _**Note:** You don't need to upload the dataset to Codegra.de, it's already available there. For your code to run properly, on Codegra.de, use a relative path to import the dataset respecting the given file structure._

# %%
df = ...
index_to_class = {0: "drugY", 1: "drugX", 2: "drugA", 3: "drugB", 4: "drugC"}
# YOUR CODE HERE

df.head()

# %% [markdown]
# [0.75 p] Is the class distribution of the dataset balanced? Write code to show it by printing/plotting the class distribution.
#
# Research what stratification means in the context of train-test splitting. Explain why it is important.

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# [0.25 p] Split the data into a training and test set (80%-20%). Use `random_state = 42` as seed and make sure you preserve class balance. Store the split data in `X_train, X_test, y_train, y_test` as numpy arrays.

# %%
X_train, X_test, y_train, y_test = ..., ..., ..., ...
# YOUR CODE HERE

# %% [markdown]
# [0.25] Standarize the data. Override `X_train` and `X_test` to store the transformed data.

# %%
#BEGIN SOLUTION
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# END SOLUTION
print(X_train[0])
print(X_test[0])

# %%
# # TESTS
expected_X_train_0 = [-1.40148211, -0.56608449, -0.89845919, 0.89845919, -0.79399923, -0.69652603, 1.57745748, 1.01342342, -1.01342342]

expected_X_test_0 = [1.18864958, 2.71598032, -0.89845919, 0.89845919, 1.25944706, -0.69652603, -0.63393151, -0.98675438, 0.98675438]
print(np.allclose(X_train[0], expected_X_train_0, atol=0.001)) 
print(np.allclose(X_test[0], expected_X_test_0, atol=0.001))

# %% [markdown]
# ## 2. Drug type prediction with kNN [1.5 p.]
# [0.5 p.] Train a k-NN classifier on the data, get the predicted labels on the test set and report the accuracy on the test set. Use `n_neighbors=5`.

# %%
y_pred = ...
accuracy = ...

# YOUR CODE HERE

print("First 5 predictions:", y_pred[:5])
print("First 5 true labels:", y_test[:5])
print("Accuracy:", f"{accuracy:.4f}")

# %% [markdown]
# [1 p.] Recall that in the first homework assignment we implemented the weighted version of kNN for regression. Discuss how you would implement the weighted version of kNN for classification. Include one example showing a classification of a test datapoint that would be different depending on the use of the weighted or non-weighted classifiers.
#
# ❗ _**Note:** this is (deliberately) an open-ended question. You can choose how to answer it: you might want to just write an explanation/pseudocode and a "pen and paper" example, or maybe you want show it using the sklearn implementation on a real dataset. Or maybe you want to implement it yourself! All these approaches are fine as long as you answer to what is asked_ 😃.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## 3. Evaluating classifiers [5.5 p.]
# ### 3.1. Confusion matrix [1 p.]
# [0.75 p.] Complete the implementation of the `confusion_matrix` function below. It should mimic the basic functionality of `sklearn.metrics.confusion_matrix`. You can assume that the class labels will be integers.See the function docstrings below for further instructions. You are not allowed to use Sklearn in this exercise. Make sure your implementation allows you to run the sample code below!

# %%
def confusion_matrix(y_true, y_pred):
    """
    Compute the confusion matrix.

    Parameters:
    - y_true: array-like of shape (n_samples,)
        Ground truth (correct) target values.
    - y_pred: array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.

    Returns:
    - cm: array-like of shape (n_classes, n_classes)
        Confusion matrix.
    """
    # YOUR CODE HERE

# %% [markdown]
# [0.25 p.] Compute the confusion matrix using the predictions and true labels from the previous question. Plot it nicely with Seaborn as we did in the tutorial.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3.2. Classification metrics [4.5 p.]
# [3 p.] Complete the implementation of the `accuracy_score`, `precision_score`, `recall_score` and `f1_score` functions below. They should mimic the basic functionality of their respectiv counterparts included in the `sklearn.metrics` module. See the function docstrings below for further instructions. You are not allowed to use Sklearn in this exercise.  Make sure your implementation allows you to run the sample code below!

# %% [markdown]
# 🔎 _**Hint:** Start implementing the `"binary"` weighting option first (there is a test for each averaging option). Once you make it work, complete your implementation for the rest of averaging strategies._

# %%
def accuracy_score(y_true, y_pred):
    """
    Compute the accuracy score.

    Parameters:
    - y_true: array-like of shape (n_samples,)
        Ground truth (correct) target values.
    - y_pred: array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.

    Returns:
    - score: float
        Accuracy score.
    """
    # YOUR CODE HERE

def precision_score(y_true, y_pred, average='binary'):
    """
    Compute the precision score.

    Parameters:
    - y_true: array-like of shape (n_samples,)
        Ground truth (correct) target values.
    - y_pred: array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.
    - average: str, optional (default='binary')
        The averaging strategy for multiclass targets. Possible values are:
        - 'binary': Only report results for the positive class (1). This is applicable only if targets (y_{true,pred}) are binary.
        - 'micro': Calculate metrics globally by counting the total true positives,
          false negatives, and false positives.
        - 'macro': Calculate metrics for each label, and find their unweighted mean.
        - 'weighted': Calculate metrics for each label, and find their average weighted
          by support (the number of true instances for each label).

    Returns:
    - score: float
        Precision score.
    """
    # YOUR CODE HERE

def recall_score(y_true, y_pred, average='binary'):
    """
    Compute the recall score.

    Parameters:
    - y_true: array-like of shape (n_samples,)
        Ground truth (correct) target values.
    - y_pred: array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.
    - average: str, optional (default='binary')
        The averaging strategy for multiclass targets. Possible values are:
        - 'binary': Only report results for the positive class (1). This is applicable only if targets (y_{true,pred}) are binary.
        - 'micro': Calculate metrics globally by counting the total true positives,
          false negatives, and false positives.
        - 'macro': Calculate metrics for each label, and find their unweighted mean.
        - 'weighted': Calculate metrics for each label, and find their average weighted
          by support (the number of true instances for each label).

    Returns:
    - score: float
        Recall score.
    """
    # YOUR CODE HERE

def f1_score(y_true, y_pred, average='binary'):
    """
    Compute the F1 score.

    Parameters:
    - y_true: array-like of shape (n_samples,)
        Ground truth (correct) target values.
    - y_pred: array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.
    - average: str, optional (default='binary')
        The averaging strategy for multiclass targets. Possible values are:
        - 'binary': Only report results for the positive class (1). This is applicable only if targets (y_{true,pred}) are binary.
        - 'micro': Calculate metrics globally by counting the total true positives,
          false negatives, and false positives.
        - 'macro': Calculate metrics for each label, and find their unweighted mean.
        - 'weighted': Calculate metrics for each label, and find their average weighted
          by support (the number of true instances for each label).

    Returns:
    - score: float
        F1 score.
    """
    # YOUR CODE HERE

y_true_toy = [0, 0, 0, 1, 1, 0, 1, 0, 1, 1]
y_pred_toy = [0, 1, 1, 1, 0, 0, 1, 0, 1, 1]

accuracy_toy = accuracy_score(y_true_toy, y_pred_toy)
precision_toy = precision_score(y_true_toy, y_pred_toy, average='binary')
recall_toy = recall_score(y_true_toy, y_pred_toy, average='binary')
f1_toy = f1_score(y_true_toy, y_pred_toy, average='binary')

print("Binary Classification Example:")
print(f"Accuracy: {accuracy_score(y_true_toy, y_pred_toy):.4f}")
print(f"Precision (binary): {precision_toy:.4f}")
print(f"Recall (binary): {recall_toy:.4f}")
print(f"F1 Score (binary): {f1_toy:.4f}")


y_true_toy = [0, 0, 0, 0, 0, 1, 1, 1, 2, 2]
y_pred_toy = [0, 0, 0, 0, 1, 0, 1, 2, 2, 2]

accuracy = accuracy_score(y_true_toy, y_pred_toy)

precision_micro = precision_score(y_true_toy, y_pred_toy, average='micro')
precision_macro = precision_score(y_true_toy, y_pred_toy, average='macro')
precision_weighted = precision_score(y_true_toy, y_pred_toy, average='weighted')

recall_micro = recall_score(y_true_toy, y_pred_toy, average='micro')
recall_macro = recall_score(y_true_toy, y_pred_toy, average='macro')
recall_weighted = recall_score(y_true_toy, y_pred_toy, average='weighted')

f1_micro = f1_score(y_true_toy, y_pred_toy, average='micro')
f1_macro = f1_score(y_true_toy, y_pred_toy, average='macro')
f1_weighted = f1_score(y_true_toy, y_pred_toy, average='weighted')

print("\nMulticlass Classification Example:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (micro): {precision_micro:.4f}")
print(f"Precision (macro): {precision_macro:.4f}")
print(f"Precision (weighted): {precision_weighted:.4f}")
print(f"Recall (micro): {recall_micro:.4f}")
print(f"Recall (macro): {recall_macro:.4f}")
print(f"Recall (weighted): {recall_weighted:.4f}")
print(f"F1 Score (micro): {f1_micro:.4f}")
print(f"F1 Score (macro): {f1_macro:.4f}")
print(f"F1 Score (weighted): {f1_weighted:.4f}")

# %% [markdown]
# [1.5 p.] Discuss the difference between the precision and recall. Mention one classification problem where precision would be more important than recall, one where recall would be more important and one where both are equally important. How does the f1-score help us mitigate unbalances between precision and recall?
#
# YOUR ANSWER HERE

# %% [markdown]
# ## 4. Evaluating the drug classifier [1.5 p.]
# [1.5 p.] Use `sklearn.metrics.classification_report` to get an overall summary of the performance of the drug classifier we defined in exercise 2. Discuss the metrics shown on the report and the confusion matrix and the limitations of our experimental setup. In this particular case, which metric(s) should we pay more attention to?

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWER HERE
